# %% [markdown]
# <a href="https://colab.research.google.com/github/UmangWasekar/IPL-T20-Cricket-Analysis/blob/main/Umang_Wasekar_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Indian Premier League(IPL) is a professional Twenty20 cricket league in India contested during March or April and May of every year by eight teams representing eight different cities in India. The league was founded by the Board of Control for Cricket in India(BCCI) in 2008. </b>
#
# ## <b> Explore and analyze the data to discover results and statistics for different teams playing in IPL. </b>

# %%
# Importing Libraries

import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Mounting Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
teams_df = pd.read_csv('/content/drive/MyDrive/Capstone Project 1/teams.csv')

home_away_df = pd.read_csv('/content/drive/MyDrive/Capstone Project 1/teamwise_home_and_away.csv')

average_df = pd.read_csv('/content/drive/MyDrive/Capstone Project 1/most_runs_average_strikerate.csv')

players_df = pd.read_excel('/content/drive/MyDrive/Capstone Project 1/Players.xlsx')

deliveries_df = pd.read_csv('/content/drive/MyDrive/Capstone Project 1/deliveries.csv')

ipl_match_df = pd.read_csv('/content/drive/MyDrive/Capstone Project 1/matches.csv')

# %%
teams_df.head(16)
# Out:
#                           team1
# 0                 Pune Warriors
# 1         Kolkata Knight Riders
# 2              Rajasthan Royals
# 3          Kochi Tuskers Kerala
# 4                 Gujarat Lions
# 5           Chennai Super Kings
# 6       Rising Pune Supergiants
# 7              Delhi Daredevils
# 8               Deccan Chargers
# 9                Delhi Capitals
# 10               Mumbai Indians
# 11          Sunrisers Hyderabad
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14              Kings XI Punjab

# %%
home_away_df.head(15)
# Out:
#                            team  ...  away_win_percentage
# 0        Rising Pune Supergiant  ...            62.500000
# 1                Mumbai Indians  ...            59.302326
# 2           Chennai Super Kings  ...            65.333333
# 3                Delhi Capitals  ...            70.000000
# 4           Sunrisers Hyderabad  ...            62.222222
# 5              Rajasthan Royals  ...            57.500000
# 6               Deccan Chargers  ...            34.375000
# 7               Kings XI Punjab  ...            51.764706
# 8   Royal Challengers Bangalore  ...            51.578947
# 9         Kolkata Knight Riders  ...            61.052632
# 10             Delhi Daredevils  ...            47.191011
# 11                Pune Warriors  ...            23.076923
# 12         Kochi Tuskers Kerala  ...            57.142857
# 13                Gujarat Lions  ...            75.000000
#
# [14 rows x 7 columns]

# %%
#Total number of Columns and Rows to analyse

print(home_away_df.shape)
print(teams_df.shape)
# Out:
# (14, 7)
# (15, 1)

# %%
Columns_home_away = list(home_away_df.columns)
Columns_teams = list(teams_df.columns)

# %%
print(Columns_home_away)
# Out:
# ['team', 'home_wins', 'away_wins', 'home_matches', 'away_matches', 'home_win_percentage', 'away_win_percentage']

# %%
print(Columns_teams)
# Out:
# ['team1']

# %%
# List of all the franchises took part in Ipl from season 1

list(teams_df['team1'].unique())
# Out:
# ['Pune Warriors',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Kochi Tuskers Kerala',
#  'Gujarat Lions',
#  'Chennai Super Kings',
#  'Rising Pune Supergiants',
#  'Delhi Daredevils',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Mumbai Indians',
#  'Sunrisers Hyderabad',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Kings XI Punjab']

# %%
# Performances of all the teams on their home conditions

plt.figure(figsize=(15,5))
home_condition_performance = home_away_df.groupby(['team'])['home_wins'].sum().sort_values(ascending=False)[:]

home_condition_performance.plot()
home_condition_performance.plot(kind = 'bar')

plt.title('Most sucessful teams at home venues')
plt.xlabel('Teams')
plt.ylabel('Most Wins')
# Out:
# Text(0, 0.5, 'Most Wins')

# %%
#  Performances of all the teams on their away conditions


plt.figure(figsize=(15,5))
away_condition_performance = home_away_df.groupby(['team'])['away_wins'].sum().sort_values(ascending=False)[:]

away_condition_performance.plot()
away_condition_performance.plot(kind = 'bar')

plt.title('Most sucessful teams at away venues')
plt.xlabel('Teams')
plt.ylabel('Most Wins')
# Out:
# Text(0, 0.5, 'Most Wins')

# %%
# Least sucessful team in taking the advantage of home condtions

plt.figure(figsize=(15,5))
home_condition_performance = home_away_df.groupby(['team'])['away_wins'].sum().sort_values(ascending=True)[:]

home_condition_performance.plot()
home_condition_performance.plot(kind = 'bar')

plt.title('Least sucessful teams at away venues')
plt.xlabel('Teams')
plt.ylabel('Least Wins')
# Out:
# Text(0, 0.5, 'Least Wins')

# %%
# Highest overall win percentage 


home_away_df['overall_win_percentage'] = (home_away_df['home_win_percentage'] + home_away_df['away_win_percentage'])/2    #Adding new column in original data frame 
overall_win_percentage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-550cf1260ca7> in <module>()
#       2
#       3
# ----> 4 home_away_df['overall_win_percentage'] = (home_away_df['home_win_percentage'] + home_away_df['away_win_percentage'])/2    #Adding new column in original data frame
#       5 overall_win_percentage
#
# NameError: name 'home_away_df' is not defined

# %%
plt.figure(figsize=(8, 5))
data = home_away_df.groupby(['team'])['overall_win_percentage'].sum().sort_values(ascending=False)[:]
sns.barplot(y=data.index, x=data , orient='h')
plt.title('Highest Overall Win Percentage')
plt.xlabel('Win Percentage')
plt.ylabel('Teams')
# Out:
# Text(0, 0.5, 'Teams')

# %%
# Lowest overall win percentage

plt.figure(figsize=(8, 5))
data = home_away_df.groupby(['team'])['overall_win_percentage'].sum().sort_values(ascending=True)[:]
sns.barplot(y=data.index, x=data , orient='h')
plt.title('Highest Overall Win Percentage')
plt.xlabel('Win Percentage')
plt.ylabel('Teams')
# Out:
# Text(0, 0.5, 'Teams')

# %%
average_df.head(10)
# Out:
#           batsman  total_runs  out  numberofballs    average  strikerate
# 0         V Kohli        5426  152           4111  35.697368  131.987351
# 1        SK Raina        5386  160           3916  33.662500  137.538304
# 2       RG Sharma        4902  161           3742  30.447205  130.999466
# 3       DA Warner        4717  114           3292  41.377193  143.286756
# 4        S Dhawan        4601  137           3665  33.583942  125.538881
# 5        CH Gayle        4525  110           2972  41.136364  152.254374
# 6        MS Dhoni        4450  118           3206  37.711864  138.802246
# 7      RV Uthappa        4420  156           3381  28.333333  130.730553
# 8  AB de Villiers        4414  104           2902  42.442308  152.101999
# 9       G Gambhir        4219  134           3400  31.485075  124.088235

# %%
# Top 5 players with most runs

plt.figure(figsize=(7, 3))
data = average_df.groupby(['batsman'])['total_runs'].sum().sort_values(ascending=False)[:5]
sns.barplot(y=data, x=data.index , orient='v')
plt.title('Most runs in IPL History')
plt.xlabel('Batsman')
plt.ylabel('Runs')
plt.show()

# %%
# Top 5 players getting dismissed most number times

plt.figure(figsize=(10,4))
data = average_df.groupby(['batsman'])['out'].sum().sort_values(ascending=False)[:5]
sns.barplot(y=data.index,x=data,orient='h')
plt.title('Most Dismissals in IPL History')
plt.xlabel('Dismissals')
plt.ylabel('Batsman')
plt.show()

# %%
# Players who faced most numbers of delivers

plt.figure(figsize=(10,4))
most_deliveries = average_df.groupby(['batsman'])['numberofballs'].sum().sort_values(ascending=False)[:5]

most_deliveries.plot()

plt.title('Most Number Of Deliveries Faced By Batsman')
plt.xlabel('Deliveries')
plt.ylabel('Batsman')

plt.rcParams['figure.figsize'] = (10, 5)

# %%
# Top 5 players with highest Batting average

plt.figure(figsize=(8,5))
most_deliveries = average_df.groupby(['batsman'])['average'].sum().sort_values(ascending=False)[:5]

most_deliveries.plot(kind='bar')

plt.title('Best Overall Batting Average')
plt.xlabel('Batsman')
plt.ylabel('Batting Average')
# Out:
# Text(0, 0.5, 'Batting Average')

# %%
# Top 5 players with highest Batting average

plt.figure(figsize=(8,5))
most_deliveries = average_df.groupby(['batsman'])['average'].sum().sort_values(ascending=True)[:5]

most_deliveries.plot(kind='bar')

plt.title('Lowest Overall Batting Average')
plt.xlabel('Batsman')
plt.ylabel('Batting Average')
# Out:
# Text(0, 0.5, 'Batting Average')

# %%
# Players with best overall batting strike rate

plt.figure(figsize=(8,5))
most_deliveries = average_df.groupby(['batsman'])['strikerate'].sum().sort_values(ascending=False)[:5]

most_deliveries.plot()

plt.title('Best Overall Batting Strike Rate')
plt.xlabel('Batsman')
plt.ylabel('Batting Strike Rate')
# Out:
# Text(0, 0.5, 'Batting Strike Rate')

# %%
# Players with lowest overall batting strike rate

plt.figure(figsize=(8,5))
most_deliveries = average_df.groupby(['batsman'])['strikerate'].sum().sort_values(ascending=True)[:5]

most_deliveries.plot()

plt.title('Lowest Overall Batting Strike Rate')
plt.xlabel('Batsman')
plt.ylabel('Batting Strike Rate')
# Out:
# Text(0, 0.5, 'Batting Strike Rate')

# %%
players_df.head()
# Out:
#       Player_Name        DOB Batting_Hand         Bowling_Skill Country
# 0  A Ashish Reddy 1991-02-24   Right_Hand      Right-arm medium   India
# 1      A Chandila 1983-12-05   Right_Hand    Right-arm offbreak   India
# 2        A Chopra 1977-09-19   Right_Hand    Right-arm offbreak   India
# 3     A Choudhary        NaT   Right_hand  Left-arm fast-medium     NaN
# 4     A Dananjaya        NaT   Right_Hand    Right-arm offbreak     NaN

# %%
# Total number of players participated in ipl till the updated data

total_players_debuted_in_ipl = players_df['Player_Name'].count()
print(total_players_debuted_in_ipl)
# Out:
# 566

# %%
# Comparision of batting hands of the players

players_df['Batting_Hand'] = players_df['Batting_Hand'].str.upper()  # Uppercasing all the rows just in case

batting_hand_type = ['RIGHT_HAND_BATTING','LEFT_HAND_BATTING']      #Labels of our pie charts
batting_hand = list(players_df['Batting_Hand'].value_counts())
fig=plt.figure(figsize=(10,7))
plt.pie(batting_hand,labels = batting_hand_type,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5c48708350>,
# ...
#  [Text(-0.7723731544638862, 0.7832239208958739, 'RIGHT_HAND_BATTING'),
#   Text(0.7723730811331669, -0.7832239932106642, 'LEFT_HAND_BATTING')],
#  [Text(-0.4212944478893924, 0.4272130477613857, '74.78%'),
#   Text(0.4212944078908183, -0.42721308720581674, '25.22%')])

# %%
# Comparison of bowlers with respect to their variations

players_df['Bowling_Skill'].unique()
# Out:
# array(['RIGHT-ARM MEDIUM', 'RIGHT-ARM OFFBREAK', 'RIGHT-ARM FAST-MEDIUM',
#        'LEGBREAK GOOGLY', 'LEGBREAK', 'LEFT-ARM MEDIUM-FAST',
#        'RIGHT-ARM MEDIUM-FAST', 'LEFT-ARM MEDIUM',
#        'SLOW LEFT-ARM ORTHODOX', 'RIGHT-ARM FAST', 'LEFT-ARM FAST-MEDIUM',
#        'LEFT-ARM FAST', 'SLOW LEFT-ARM CHINAMAN', 'RIGHT-ARM BOWLER'],
#       dtype=object)

# %%
players_df['Bowling_Skill'] = players_df['Bowling_Skill'].str.upper()              # Uppercasing all the rows just in case

bowling_type = ['RIGHT-ARM MEDIUM', 'RIGHT-ARM OFFBREAK', 'LEFT-ARM FAST-MEDIUM',
       'RIGHT-ARM FAST-MEDIUM','RIGHT-ARM FAST', 'LEGBREAK GOOGLY',
       'LEGBREAK', 'LEFT-ARM MEDIUM-FAST', 'SLOW LEFT-ARM ORTHODOX',
       'RIGHT-ARM MEDIUM-FAST', 'LEFT-ARM MEDIUM', 'LEFT-ARM FAST',
       'SLOW LEFT-ARM CHINAMAN', 'RIGHT-ARM BOWLER']                               #Labels of our pie charts
bowling_type_variations = list(players_df['Bowling_Skill'].value_counts())
fig=plt.figure(figsize=(15,21))
plt.pie(bowling_type_variations,labels = bowling_type,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f42fac1e490>,
# ...
#  [Text(0.8581720613183926, 0.6881429453046375, 'RIGHT-ARM MEDIUM'),
#   Text(-0.3776593667340943, 1.0331376494533548, 'RIGHT-ARM OFFBREAK'),
#   Text(-1.0722014637809287, 0.24573160371843497, 'LEFT-ARM FAST-MEDIUM'),
#   Text(-0.9583126034726718, -0.5400342156062242, 'RIGHT-ARM FAST-MEDIUM'),
#   Text(-0.5219480726426852, -0.9682820918846875, 'RIGHT-ARM FAST'),
#   Text(-0.006883768755652881, -1.0999784605744418, 'LEGBREAK GOOGLY'),
#   Text(0.44782967660014933, -1.004713183329554, 'LEGBREAK'),
#   Text(0.7753799329815988, -0.7802473707289578, 'LEFT-ARM MEDIUM-FAST'),
#   Text(0.9682821163188393, -0.5219480273141281, 'SLOW LEFT-ARM ORTHODOX'),
#   Text(1.0486854187984964, -0.3320525446362705, 'RIGHT-ARM MEDIUM-FAST'),
#   Text(1.0819341766376835, -0.19854077017916955, 'LEFT-ARM MEDIUM'),
#   Text(1.0951569731966664, -0.10310773035382012, 'LEFT-ARM FAST'),
#   Text(1.099224642184615, -0.04129389802507787, 'SLOW LEFT-ARM CHINAMAN'),
# ...

# %%
# Comparision of players debuted from each nation 

players_df['Country'].unique()
# Out:
# array(['India', 'England', 'South Africa', 'Australia', 'Bangladesh',
#        'Sri Lanka', 'West Indies', 'New Zealand', 'Pakistan',
#        'Netherlands', 'Zimbabwea'], dtype=object)

# %%
total_nations = ['India', 'England', 'South Africa', 'Australia', 'Bangladesh',
       'Sri Lanka', 'West Indies', 'New Zealand', 'Pakistan',
       'Netherlands', 'Zimbabwea']
nations = list(players_df['Country'].value_counts())
fig=plt.figure(figsize=(15,11))
plt.pie(nations ,labels = total_nations , autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f42faad1210>,
# ...
#  [Text(-0.20784891199504588, 1.0801846276366258, 'India'),
#   Text(-0.7173174652234344, -0.8339398384088791, 'England'),
#   Text(0.03301185846553083, -1.0995045325966837, 'South Africa'),
#   Text(0.4654342204537462, -0.9966799819553986, 'Australia'),
#   Text(0.72286398666088, -0.8291366936692279, 'Bangladesh'),
#   Text(0.9118045865060566, -0.6153148755121393, 'Sri Lanka'),
#   Text(1.0241525009786134, -0.40138716314706874, 'West Indies'),
#   Text(1.079485460066797, -0.2114500922307105, 'New Zealand'),
#   Text(1.0970405541621218, -0.0806351196667113, 'Pakistan'),
#   Text(1.0996085171487773, -0.029344659034779976, 'Netherlands'),
#   Text(1.099975531323315, -0.007336926467596929, 'Zimbabwea')],
#  [Text(-0.11337213381547956, 0.5891916150745231, '56.05%'),
#   Text(-0.3912640719400551, -0.45487627549575216, '15.29%'),
#   Text(0.018006468253925902, -0.5997297450527365, '8.28%'),
# ...

# %%
# Deliveries Bowled in each innings 

inning=deliveries_df['inning'].value_counts()
a=dict(inning)
innings=list(a.keys())
inning_deliveries=list(a.values())
plt.bar(innings,inning_deliveries)
plt.title('Deliveries Bowled in each inning',fontsize=15,color='red')
plt.xlabel('Innings')
plt.ylabel('Deliveries Bowled')
plt.show()

# %%
# Comparision of Normal and Extra deliveries Bowled

deleveries=deliveries_df['ball'].value_counts()     #It gets the number of balls in over including the extra deleveries. 
deleveris_list=list(deleveries)           #Converting it into list provides easy option to count the legal deliveries
legal_deliveries=sum(deleveris_list[0:6])   # here we count the legal deleviries from 0 to 6 balls and eliminate the extra deliveries bowled
extra_deleveries=sum(deleveris_list[6:])     # counting how many extra balls bowled
wide_deliveries_list = list(deliveries_df['wide_runs'].value_counts())
no_of_wide_ball_bowled=sum(wide_deliveries_list[1:])   #counting the wide deliveries bowled
no_ball_list = list(deliveries_df['noball_runs'].value_counts())
no_of_no_ball_bowled=sum(no_ball_list[1:])   #counting the no ball deliveries bowled

#formulating a pie chart for the deliveries thrown.
deliveries_type= ['Normal deliveries','Wicket Deliveries','no_of_wide_ball_bowled','no_of_no_ball_bowled']
deliveries_count=[164214,8834,5405,714]
fig=plt.figure(figsize=(15,10.5))
colors=('grey','red','pink','blue')
plt.pie(deliveries_count,labels=deliveries_type,colors=colors,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd9e8635050>,
# ...
#  [Text(-1.0624064443253733, 0.28511847898008563, 'Normal deliveries'),
#   Text(1.0257645923215888, -0.3972492934409384, 'Wicket Deliveries'),
#   Text(1.0921141494541595, -0.1314788369359036, 'no_of_wide_ball_bowled'),
#   Text(1.099913796167528, -0.013771020308529867, 'no_of_no_ball_bowled')],
#  [Text(-0.5794944241774763, 0.15551917035277396, '91.65%'),
#   Text(0.5595079594481392, -0.21668143278596638, '4.93%'),
#   Text(0.595698626974996, -0.07171572923776558, '3.02%'),
#   Text(0.5999529797277424, -0.007511465622834472, '0.40%')])

# %%
#Run Scored on Balls :

deliveries_distribution =deliveries_df['batsman_runs'].value_counts()
deliveries_distribution.plot.bar(figsize=(15,8),color='brown')
plt.title('Deliveries Distribution according to Run scored')
plt.ylabel('Deliveries Count')
plt.xlabel('Run Count')
# Out:
# Text(0.5, 0, 'Run Count')

# %%
#Most wicket taking Bowlers in IPL

bowler_df=deliveries_df.groupby('bowler')['player_dismissed'].count()
top_wicket_taking_bowler=bowler_df.sort_values(ascending=False).head(10)
top_wicket_taking_bowler.plot(figsize=(15,8))
plt.xlabel("Name of Bowler",color='green')
plt.ylabel("Number of Wickets Taken",color='green')
plt.title('Most Wicket Taking Bowlers in IPL',color='red',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most Wicket Taking Bowlers in IPL')

# %%
# Bowling Average

bowler_df1=deliveries_df.groupby('bowler')['total_runs'].sum()
print(bowler_df1)
bowling_avg = (bowler_df1/bowler_df).sort_values()
print(bowling_avg)              # We  will get infinite value for those who bowled some overs but didn't get any wickets.
bowling_avg.head(35).plot(kind='bar',figsize=(22,8))
plt.ylabel(' Average',fontsize=20,color='black')
plt.title('Bowling Average',fontsize=30,color='red')
# Out:
# bowler
# A Ashish Reddy     400
# A Chandila         245
# A Choudhary        144
# A Dananjaya         48
# A Flintoff         106
#                   ...
# YA Abdulla         311
# YK Pathan         1443
# YS Chahal         2416
# Yuvraj Singh      1092
# Z Khan            2860
# Name: total_runs, Length: 405, dtype: int64
# bowler
# AC Gilchrist     0.000000
# Sachin Baby      2.666667
# AM Rahane        5.000000
# LA Carseldine    6.000000
# SS Mundhe        6.000000
#                    ...
# Mandeep Singh         inf
# S Dube                inf
# C Ganapathy           inf
# L Livingstone         inf
# NJ Rimmington         inf
# Length: 405, dtype: float64
# Text(0.5, 1.0, 'Bowling Average')

# %%
# Averages for all Bowlers
plt.scatter(bowler_df,bowling_avg)
plt.figure(figsize=(15,8), dpi=150)

# %%
#toss Decisions 

toss_decision_type =['Field','Bat']
toss_decison=list(ipl_match_df['toss_decision'].value_counts())
fig=plt.figure(figsize=(15,10.5))
plt.title('Toss decisions',fontsize=25)
plt.pie(toss_decison,labels=toss_decision_type,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd9e792dd10>,
# ...
#  [Text(-0.3805142883934777, 1.032089567977705, 'Field'),
#   Text(0.3805142883934778, -1.032089567977705, 'Bat')],
#  [Text(-0.20755324821462415, 0.5629579461696571, '61.24%'),
#   Text(0.20755324821462423, -0.5629579461696571, '38.76%')])

# %%
#Team decision of of batting or fielding after winning of toss effect on match result

#Winning percetage after choosing Field or Bat in toss decision
Counts_of_toss_decsion =list(ipl_match_df['toss_decision'].value_counts())
print(Counts_of_toss_decsion)
toss_decision=list(ipl_match_df['toss_decision'])
print(toss_decision)
team_winning_toss=list(ipl_match_df['toss_winner'])
print(team_winning_toss)
winner=list(ipl_match_df['winner'])
fielding_decision_count=0
print(winner)
i=0
batting_decision_count=0
j=0
while i<len(toss_decision):
 if toss_decision[i]=='field':
  if team_winning_toss[i]==winner[i]:
   i=i+1
   fielding_decision_count=fielding_decision_count+1
  else:
   i=i+1
 else:
  i=i+1
while j<len(toss_decision):
 if toss_decision[j]=='bat':
  if team_winning_toss[j]==winner[j]:
   j=j+1
   batting_decision_count=batting_decision_count+1
  else:
   j=j+1
 else:
  j=j+1

print(fielding_decision_count)
print(batting_decision_count)

plt.figure(figsize=(6,8))
Y_axis_data = [fielding_decision_count*100/Counts_of_toss_decsion[0],batting_decision_count*100/Counts_of_toss_decsion[1]]
x_axis_data =['field','Bat']
sns.barplot(y=Y_axis_data,x=x_axis_data,orient='v',)
plt.ylim([0,70])
plt.text(0,Y_axis_data[0],'55.93%')
plt.text(1,Y_axis_data[1],'45.77%')
# Out:
# [463, 293]
# ...

# %%
#Rain affected Matches

a=ipl_match_df['dl_applied'].value_counts()
match= ['Normal MAtches','Duckword Lewis Applied']
match_count=[737,19]
colors=("yellow","red")
fig=plt.figure(figsize=(15,10.5))
plt.pie(match_count,labels=match,colors=colors,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd9e78dc9d0>,
# ...
#  [Text(-1.0965731016216453, 0.08676077915674248, 'Normal MAtches'),
#   Text(1.0965730950215986, -0.08676086257496675, 'Duckword Lewis Applied')],
#  [Text(-0.5981307827027156, 0.04732406135822316, '97.49%'),
#   Text(0.5981307791026901, -0.04732410685907277, '2.51%')])
